# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data = pd.read_csv("Iris.csv", names=['Id','sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
iris_data.head()
# Out:
#    Id  sepal_length  sepal_width  petal_length  petal_width        class
# 0  Id  sepal_length  sepal_width  petal_length  petal_width      species
# 1   1           5.1          3.5           1.4          0.2  Iris-setosa
# 2   2           4.9          3.0           1.4          0.2  Iris-setosa
# 3   3           4.7          3.2           1.3          0.2  Iris-setosa
# 4   4           4.6          3.1           1.5          0.2  Iris-setosa

# %%
iris_data.tail()
# Out:
#       Id sepal_length sepal_width petal_length petal_width           class
# 146  146          6.7         3.0          5.2         2.3  Iris-virginica
# 147  147          6.3         2.5          5.0         1.9  Iris-virginica
# 148  148          6.5         3.0          5.2         2.0  Iris-virginica
# 149  149          6.2         3.4          5.4         2.3  Iris-virginica
# 150  150          5.9         3.0          5.1         1.8  Iris-virginica

# %%
iris_data.describe()
# Out:
#          Id sepal_length sepal_width petal_length petal_width        class
# count   151          151         151          151         151          151
# unique  151           36          24           44          23            4
# top      Id          5.0         3.0          1.5         0.2  Iris-setosa
# freq      1           10          26           14          28           50

# %%
#Length of Data
iris_data.shape
# Out:
# (151, 6)

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            151 non-null    object
#  1   sepal_length  151 non-null    object
#  2   sepal_width   151 non-null    object
#  3   petal_length  151 non-null    object
#  4   petal_width   151 non-null    object
#  5   class         151 non-null    object
# dtypes: object(6)
# memory usage: 7.2+ KB

# %%
#Checking null value
iris_data.isnull().sum()
# Out:
# Id              0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
train_X = train_test_split[['sepal_length','sepal_width','petal_length','petal_width','species']]
train_y = train.species
test_X = test[['sepal_length','sepal_width','petal_length','petal_width','species']]
test_y = test.species
#print accuracy of each model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 train_X = train[['sepal_length','sepal_width','petal_length','petal_width','species']]
#       2 train_y = train.species
#       3 test_X = test[['sepal_length','sepal_width','petal_length','petal_width','species']]
#
# NameError: name 'train' is not defined

# %%
iris_data['Species'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# ...

# %%
iris_data['sepal_width'].hist()
plt.show()

# %%
iris_data['sepal_length'].hist()
plt.show()

# %%
iris_data['petal_width'].hist()
plt.show()

# %%
iris_data['petal_length'].hist()
plt.show()

# %%
s = sns.FacetGrid(iris_data, height=8, hue="species")
s.map(plt.scatter, "petal_length", "petal_width")
s.add_legend()
sns.set_style("whitegrid")
plt.show()

# %%
s = sns.FacetGrid(iris_data, height=8, hue="species")
s.map(plt.scatter, "sepal_length", "sepal_width")
s.add_legend()
sns.set_style("whitegrid")
plt.show()

# %%
sns.pairplot(iris_data, height=2.5, hue="species")
plt.show()

# %%
sns.heatmap(iris_data.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sns.heatmap(iris_data.corr(), annot=True)
#       2 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
